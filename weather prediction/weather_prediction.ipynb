# %% [markdown]
# **Weather Prediction**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\user\Desktop\feynn internship\weather prediction\Farm_Weather_Data.csv")

# %%
data.head()
# Out:
#             Date  MaxT  MinT  WindSpeed  Humidity   Precipitation
# 0  08-01-06 0:00  29.5  21.8        1.6       70.2            0.0
# 1  09-01-06 0:00  30.1  21.0        1.6       67.4            0.0
# 2  10-01-06 0:00  29.9  21.1        1.7       65.2            0.0
# 3  11-01-06 0:00  29.8  20.8        1.5       69.0            0.0
# 4  12-01-06 0:00  29.6  20.5        2.1       69.5            0.0

# %%
data.shape
# Out:
# (6236, 6)

# %%
data.isna().sum()
# Out:
# Date             0
# MaxT             0
# MinT             0
# WindSpeed        0
# Humidity         0
# Precipitation    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           6236 non-null   object
#  1   MaxT           6236 non-null   float64
#  2   MinT           6236 non-null   float64
#  3   WindSpeed      6236 non-null   float64
#  4   Humidity       6236 non-null   float64
#  5   Precipitation  6236 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 292.4+ KB

# %% [markdown]
# ---------------------------------------------------------------------------------------------
# visualization

# %%
sns.pairplot(data=data)
plt.show()

# %%
sns.histplot(data=data,kde=True)
plt.show()

# %%
data_dropped=data.drop(['Date'],axis=1)
sns.heatmap(data_dropped.corr(),annot=True,cmap="coolwarm")
plt.title("correlation matrix")
plt.show()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------
# Model Building

# %%
from sklearn.model_selection import train_test_split
X=data_dropped
y=data['Precipitation']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=30)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print("mean absolute error",mean_absolute_error(y_test,y_pred))
print("mean squared error",mean_squared_error(y_test,y_pred))
r2_score(y_test,y_pred)
# Out:
# mean absolute error 3.332488550959286e-15
# mean squared error 1.771713704803987e-29
# 1.0
